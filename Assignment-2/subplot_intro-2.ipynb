# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2*np.pi,100)
# An array with the sine of all the values in array x
y1 = np.sin(x)
y2 = np.cos(x)

# %%
# Create a base figure to which two subplots are added. 
#figsize is a tuple of the width and height of the figure in inches, 
# and dpi is the dots-per-inch (pixel per inch)
fig = plt.figure(figsize=(10,5))
# Adds a subplot to the array
ax1 = fig.add_subplot(1,2,1)  #for now, let's not dwell upon what those numbers in the parenthesis mean. We'll see shortly.
# Plots the sine function on the first subplot.
#it basically just means we want a 'one row two column layout'. The third '1' means we are now dedicating the first spot
#to this plot.
ax1.plot(x,y1,'r')
ax1.set_title("Sine function")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.grid(True)
# Plots the cosine function on the second subplot
ax2 = fig.add_subplot(1,2,2)

ax2.plot(x,y2,'g')
ax2.set_title("Cosine function")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.grid(True)
#to ensure no overlapping
plt.tight_layout()

# %%
#what do those numbers in the subplot function mean?
#if you are familiar with Matlab, then this shouldn't come as surprize to you.
#they are used to specify the layout of the base figure and the position of a subplot. 
#it takes a little experimenting though to understand it.
fig0 = plt.figure()
fig0.add_subplot(221)   #top left
fig0.add_subplot(222)   #top right
fig0.add_subplot(223)   #bottom left
fig0.add_subplot(224)   #bottom right 
plt.show()

# %%
#you can get pretty creative and even over the board with layout.
# I would advise against that. 
#may as well just make more plots instead of jaming everything into one plot. 
fig0 = plt.figure()
fig0.add_subplot(1, 2, 1)   #top and bottom left
fig0.add_subplot(2, 2, 2)   #top right
fig0.add_subplot(2, 2, 4)   #bottom right 
plt.show()

# %%
#Another way to create subplots is we may create two subplots all at once.
fig, ax = plt.subplots(1,2, figsize = (10,5))
# Plots the sine function on the first subplot
ax[0].plot(x,y1,'r')
ax[0].set_title("Sine function")
ax[0].set_xlabel("x")
ax[0].set_ylabel("y")
ax[0].grid(True)
# Plots the cosine function on the second subplot
ax[1].plot(x,y2,'g')
ax[1].set_title("Cosine function")
ax[1].set_xlabel("x")
ax[1].set_ylabel("y")
ax[1].grid(True)
#to ensure no overlapping
plt.tight_layout()
